# %% [markdown]
# ### Step 1: Load the packages

# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2: Load the JSON file and convert it to a data frame

# %%
f = open("product_info.json", "r")
json_file = json.load(f)
f.close()

df_luwak = pd.DataFrame(json_file)
df_luwak.head(10)
# Out:
#                                         product_name  \
# 0  Kopi Luwak von freilebenden Tieren (Kaffeebohn...
# 1  Kaffee-Bohnen aus Guatemala (NÂ°12) - Feinster...
# 2  LUCIFER'S ROAST Espresso by KIQO aus Italien -...
# 3  Kopi King Jamaica Blue Mountain | Sortenreiner...
# 4  Lavazza CaffÃ¨ Crema Classico, 1kg-Packung, Ar...
# 5  Kaffee Katzenkaffee Kopi Luwak Arabica (Von Fr...
# 6  Kaffee Katzenkaffee Kopi Luwak Arabica (Von Fr...
# 7  BARISTA ROYAL Bio Kaffeebohnen 500g "Seleccion...
# 8  Tasse Kaffeetasse mit Katze KÃ¤tzchen Samtpfot...
# 9  KARAMAN KAFFEE - Indonesian Wild Kopi Luwak Pr...
#
#                                      main_image_link  price  \
# 0  https://m.media-amazon.com/images/I/41zfeXQ8r7...  41.99
# 1  https://m.media-amazon.com/images/I/31iYbufFdl...  15.95
# 2  https://m.media-amazon.com/images/I/31gV4ovrvs...  20.66
# 3  https://m.media-amazon.com/images/I/41A7bYFaqz...  18.90
# 4  https://m.media-amazon.com/images/I/41+lAMhSzl...  13.48
# ...
